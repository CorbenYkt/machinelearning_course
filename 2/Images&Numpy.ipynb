# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
# to show images inline  the notebook

# %%
from PIL import Image
#image function that allows us to open  images

# %%
pic =  Image.open('rc1.png')

# %%
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=788x590>

# %%
type(pic)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
pic_arr = np.asarray(pic) 
#very important how to convert images into arrays

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape #resolution
# Out:
# (590, 788, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red) #copied

# %%
#zeroing out RGB values
# R G B  format
pic_red[:,:,]
# Out:
# array([[[ 86,  92,  21],
#         [ 85,  91,  19],
#         [ 84,  89,  17],
#         ...,
#         [ 90,  90,  90],
#         [ 90,  90,  90],
#         [255, 255, 255]],
#
#        [[ 83,  89,  16],
#         [ 82,  88,  14],
#         [ 80,  86,  12],
#         ...,
#         [ 91,  91,  91],
#         [ 91,  91,  91],
#         [255, 255, 255]],
#
#        [[ 81,  87,  12],
#         [ 79,  86,  10],
#         [ 78,  85,   8],
#         ...,
#         [ 92,  92,  92],
#         [ 92,  92,  92],
#         [255, 255, 255]],
#
#        ...,
#
#        [[  3,   3,   1],
#         [  2,   3,   1],
#         [  2,   5,   2],
#         ...,
#         [  0,  18,  19],
#         [  0,  17,  18],
#         [255, 255, 255]],
#
#        [[  1,   2,   0],
#         [  1,   3,   0],
#         [  3,   5,   3],
#         ...,
#         [  0,  17,  17],
#         [  0,  15,  15],
#         [255, 255, 255]],
#
#        [[  1,   2,   0],
#         [  1,   3,   0],
#         [  3,   5,   3],
# ...

# %%
plt.imshow(pic_red[:,:,0])
#colormap has changed

# %%
plt.imshow(pic_red[:,:,2],cmap='gray')

# %%
plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
#red channels values 0 no red, pure black -255 full pure red

# %%
#green channel (1)
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)

# %%
#blue channel (2)
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
plt.imshow(pic_arr[:,:,:])
#colormap has changed

# %%
pic_arr
# Out:
# array([[[ 86,  92,  21],
#         [ 85,  91,  19],
#         [ 84,  89,  17],
#         ...,
#         [ 90,  90,  90],
#         [ 90,  90,  90],
#         [255, 255, 255]],
#
#        [[ 83,  89,  16],
#         [ 82,  88,  14],
#         [ 80,  86,  12],
#         ...,
#         [ 91,  91,  91],
#         [ 91,  91,  91],
#         [255, 255, 255]],
#
#        [[ 81,  87,  12],
#         [ 79,  86,  10],
#         [ 78,  85,   8],
#         ...,
#         [ 92,  92,  92],
#         [ 92,  92,  92],
#         [255, 255, 255]],
#
#        ...,
#
#        [[  3,   3,   1],
#         [  2,   3,   1],
#         [  2,   5,   2],
#         ...,
#         [  0,  18,  19],
#         [  0,  17,  18],
#         [255, 255, 255]],
#
#        [[  1,   2,   0],
#         [  1,   3,   0],
#         [  3,   5,   3],
#         ...,
#         [  0,  17,  17],
#         [  0,  15,  15],
#         [255, 255, 255]],
#
#        [[  1,   2,   0],
#         [  1,   3,   0],
#         [  3,   5,   3],
# ...

# %%
plt.imshow(pic_arr[:,:])
