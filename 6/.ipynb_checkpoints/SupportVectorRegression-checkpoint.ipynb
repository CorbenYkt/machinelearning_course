# %%
from IPython.display import Image
Image(filename='1.png')

# %% [raw]
# Some things to keep in mind while studying SVR
#
# Hyperplane: Used to split the data into two classes, higher dimension, and actual dimension. In SVR hyperplane is used to predict continuous values.
#
# Kernel: Helps in mapping lower-dimensional data points to higher dimensional data points. There are many types of kernels like polynomial kernel, Gaussian kernel, Gaussian radial basis function, etc.
#
# Boundary Line: Parallel lines are drawn along two sides of the support vector used to define the threshold and have a value of epsilon.
#
# Support Vector: Line from where the distance is minimum between two boundary points.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("Salary_Data.csv")
X = dataset.iloc[:,0:1].values
y = dataset.iloc[:,1].values

# %%
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [raw]
# loc gets rows (or columns) with particular labels from the index.
# iloc gets rows (or columns) at particular positions in the index (so it only takes integers).

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y.reshape(-1,1))

# %% [raw]
# StandardScaler() is used to transform the data such that the data has a mean value between 0 and 1. The .fit_transform() is used to the required scale.

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = "rbf")
regressor.fit(X,y)
# Out:
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVR()

# %% [raw]
# We are using one of the most common kernels ie Gaussian RBF. The regressor.fit(X,y) is used to apply SVR to our model.

# %%
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = "red") 
plt.title("Years VS Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = "red") 
plt.plot(sc_X.inverse_transform(X),sc_y.inverse_transform(regressor.predict(X)), color = "blue") #regressor with plot
plt.title("Years VS Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()
